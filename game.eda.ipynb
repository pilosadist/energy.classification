# %%
#import libraries for EDA

import pandas as pd
from matplotlib import pyplot as plot
import seaborn as sns

# %%
#load dataset

import os.path

datasetdir = os.path.join('.', 'dataset')
filename = 'games.csv'
path = os.path.join(datasetdir, filename)

data = pd.read_csv(path, index_col='id')

# %%
data['first_release_date'] = pd.to_datetime(data['first_release_date'], unit='s')
data['involved_companies'].fillna(value='1', inplace=True)
data['genres'].fillna(value='', inplace=True)
data['involved_companies'].fillna(value='', inplace=True)
data['keywords'].fillna(value='', inplace=True)
data['summary'].fillna(value='', inplace=True)

# %%
data
# Out:
#         category  rating  rating_count  aggregated_rating first_release_date  \
# id
# 56115          0     NaN           NaN                NaN         1970-06-30
# 11304          0     NaN           NaN                NaN         1970-09-12
# 76506          0     NaN           NaN                NaN         1970-12-31
# 11485          0     NaN           NaN               50.0         1971-07-01
# 11396          0     NaN           NaN                NaN         1971-09-01
# ...          ...     ...           ...                ...                ...
# 148057         0     NaN           NaN                NaN         2025-05-01
# 165549         0     NaN           NaN                NaN         2025-12-31
# 214912         0     NaN           NaN                NaN         2025-12-31
# 83563          0     NaN           NaN                NaN         2030-01-12
# 123757         0     NaN           NaN                NaN         2030-12-20
#
#         follows game_modes        genres involved_companies  \
# id
# 56115       NaN        NaN             5                  1
# 11304       NaN          1                      91161 91162
# 76506       NaN          1         13 32      150176 150177
# 11485       NaN          1       5 15 30              50077
# 11396       3.0          2             5              46322
# ...         ...        ...           ...                ...
# 148057      NaN          1  2 9 31 32 34             135411
# 165549      NaN        NaN            34             146855
# 214912      NaN          1            12             185357
# 83563       NaN        1 2          5 32             154804
# 123757      NaN          1      10 14 32             176923
#
#                                                  keywords  \
# id
# 56115   1 72 444 453 992 1025 1033 1208 1459 1739 2841...
# 11304                                         9 2396 4260
# 76506
# 11485                               934 947 970 1025 8241
# 11396                                  947 970 1025 10211
# ...                                                   ...
# 148057    117 126 1416 3707 17147 24057 24401 28654 28655
# 165549
# 214912
# 83563                                        466 974 3682
# 123757
#
#                                                   summary multiplayer_modes  \
# id
# 56115   An early 3D flight simulator game, released by...               NaN
# 11304   Highnoon is a BASIC game developed by Christop...               NaN
# 76506   The Game of Life, also known simply as Life, i...               NaN
# 11485   Star Trek is a text-based computer game that p...               NaN
# 11396   Galaxy Game is one of the earliest known coin-...               NaN
# ...                                                   ...               ...
# 148057  Pandorex is a Point & Click Adventure featurin...               NaN
# 165549  The sequel would be a direct continuation of t...               NaN
# 214912  Penny Blood is a alternative history horror JR...               NaN
# 83563   Enjoy the thrill of the hunt in this 6 degree ...               NaN
# 123757  VR flight game developed for VR devices.The pl...               NaN
#
#                     name    platforms player_perspectives  \
# id
# 56115         Jet Rocket           52                   1
# 11304           Highnoon       82 107                   5
# 76506       Game of Life  6 69 91 103                 NaN
# 11485          Star Trek      104 106                   5
# 11396        Galaxy Game          108                   3
# ...                  ...          ...                 ...
# 148057          Pandorex            6                   4
# 165549  Butterfly Soup 2         6 14                   5
# 214912       Penny Blood    6 167 169                   2
# 83563          NeptuneGL            6                   1
# 123757        PilotXross          163                 NaN
#
#                                             similar_games       themes
# id
# 56115   8559 10964 11171 15536 28751 57217 58075 64311...            1
# 11304   18290 58867 62473 79064 100800 103301 103302 1...            1
# 76506   28277 33603 37419 44087 51577 65827 76263 7913...          NaN
# 11485   13200 13660 17130 24620 34823 55038 57187 6828...           18
# 11396   17130 24620 55038 57187 68286 68287 78770 1032...           18
# ...                                                   ...          ...
# 148057  236 11367 18011 18841 24426 25222 26870 27725 ...     17 27 43
# 165549  19075 135063 137068 140022 141888 144502 14510...        27 44
# 214912  27092 54775 69007 96217 99118 106987 113636 11...  17 19 22 43
# 83563   32902 43367 76263 96217 102868 105049 105269 1...            1
# 123757  37419 87673 96217 106987 111130 113661 113895 ...            1
#
# [103487 rows x 17 columns]
