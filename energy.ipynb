# %%
#import libraries for EDA

import pandas as pd
from matplotlib import pyplot as plot
import seaborn as sns

# %%
#load dataset

import os.path

datasetdir = os.path.join('.', 'dataset')
filename = 'owid-energy-data.csv'
path = os.path.join(datasetdir, filename)

data = pd.read_csv(path)

# %%
data[['country', 'year', 'gdp', 'coal_production', 'coal_consumption', 'coal_electricity','primary_energy_consumption', 'electricity_generation']].iloc[10073:10110]
# Out:
#           country  year           gdp  coal_production  coal_consumption  \
# 10073  Kazakhstan  1985  1.822904e+11          666.059           443.498
# 10074  Kazakhstan  1986  1.845923e+11          699.672           465.968
# 10075  Kazakhstan  1987  1.834695e+11          722.760           484.157
# 10076  Kazakhstan  1988  1.986299e+11          725.016           505.021
# 10077  Kazakhstan  1989  1.976693e+11          699.644           482.017
# 10078  Kazakhstan  1990  1.949410e+11          663.758           450.307
# 10079  Kazakhstan  1991  1.744295e+11          657.506           439.575
# 10080  Kazakhstan  1992  1.660439e+11          637.492           442.820
# 10081  Kazakhstan  1993  1.515727e+11          561.884           402.126
# 10082  Kazakhstan  1994  1.332218e+11          524.653           393.372
# 10083  Kazakhstan  1995  1.229509e+11          417.734           317.690
# 10084  Kazakhstan  1996  1.242260e+11          385.178           283.743
# ...
