# %%
#import libraries for EDA

import pandas as pd
from matplotlib import pyplot as plot
import seaborn as sns

# %%
#load dataset

import os.path

datasetdir = os.path.join('.', 'dataset')
filename = 'owid-energy-data.csv'
path = os.path.join(datasetdir, filename)

data = pd.read_csv(path)

# %%
data[['country', 'year', 'gdp']].iloc[500:550]
# Out:
#      country  year           gdp
# 500  Albania  1983  1.079598e+10
# 501  Albania  1984  1.108009e+10
# 502  Albania  1985  1.137146e+10
# 503  Albania  1986  1.166974e+10
# 504  Albania  1987  1.197530e+10
# 505  Albania  1988  1.229642e+10
# 506  Albania  1989  1.261702e+10
# 507  Albania  1990  1.294785e+10
# 508  Albania  1991  9.375844e+09
# 509  Albania  1992  8.745681e+09
# 510  Albania  1993  9.636359e+09
# 511  Albania  1994  1.059613e+10
# 512  Albania  1995  1.160073e+10
# 513  Albania  1996  1.272738e+10
# 514  Albania  1997  1.139651e+10
# 515  Albania  1998  1.246671e+10
# 516  Albania  1999  1.415186e+10
# 517  Albania  2000  1.521426e+10
# 518  Albania  2001  1.656384e+10
# 519  Albania  2002  1.740807e+10
# 520  Albania  2003  1.846550e+10
# 521  Albania  2004  1.958788e+10
# 522  Albania  2005  2.078108e+10
# 523  Albania  2006  2.212429e+10
# 524  Albania  2007  2.357465e+10
# 525  Albania  2008  2.547694e+10
# 526  Albania  2009  2.647139e+10
# 527  Albania  2010  2.759827e+10
# 528  Albania  2011  2.845265e+10
# 529  Albania  2012  2.885538e+10
# 530  Albania  2013  2.914264e+10
# 531  Albania  2014  2.967564e+10
# 532  Albania  2015  3.044453e+10
# 533  Albania  2016  3.148182e+10
# 534  Albania  2017  3.267876e+10
# 535  Albania  2018  3.400911e+10
# 536  Albania  2019           NaN
# 537  Albania  2020           NaN
# 538  Algeria  1900           NaN
# 539  Algeria  1901           NaN
# 540  Algeria  1902           NaN
# 541  Algeria  1903           NaN
# 542  Algeria  1904           NaN
# 543  Algeria  1905           NaN
# 544  Algeria  1906           NaN
# 545  Algeria  1907           NaN
# 546  Algeria  1908           NaN
# 547  Algeria  1909           NaN
# 548  Algeria  1910           NaN
# 549  Algeria  1911           NaN
